# %%
from keras.datasets import imdb
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  31050,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  12118,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %%
len(X_train[2])
# Out:
# 141

# %%
from tensorflow.keras.utils import pad_sequences
X_train = pad_sequences(X_train,padding='post',maxlen=50)
X_test = pad_sequences(X_test,padding='post',maxlen=50)

# %%
X_train[0]
# Out:
# array([2071,   56,   26,  141,    6,  194, 7486,   18,    4,  226,   22,
#          21,  134,  476,   26,  480,    5,  144,   30, 5535,   18,   51,
#          36,   28,  224,   92,   25,  104,    4,  226,   65,   16,   38,
#        1334,   88,   12,   16,  283,    5,   16, 4472,  113,  103,   32,
#          15,   16, 5345,   19,  178,   32])

# %%
model = Sequential()

model.add(SimpleRNN(32,input_shape=(50,1),return_sequences=False))
model.add(Dense(1,activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)             │ (None, 32)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.5071 - loss: 0.6986 - val_accuracy: 0.5034 - val_loss: 0.6934
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5004 - loss: 0.6932 - val_accuracy: 0.5006 - val_loss: 0.6953
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5080 - loss: 0.6937 - val_accuracy: 0.5040 - val_loss: 0.6939
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5126 - loss: 0.6924 - val_accuracy: 0.5049 - val_loss: 0.6939
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5093 - loss: 0.6921 - val_accuracy: 0.5024 - val_loss: 0.6934

# %% [markdown]
# **RNN MOdel on Mnist Dataset**

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
x_train = x_train.reshape(-1, 28, 28)  
x_test = x_test.reshape(-1, 28, 28)

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(SimpleRNN(128, input_shape=(28, 28), return_sequences=False))  
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.7601 - loss: 0.7670 - val_accuracy: 0.9374 - val_loss: 0.1988
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9410 - loss: 0.1938 - val_accuracy: 0.9575 - val_loss: 0.1417
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9576 - loss: 0.1393 - val_accuracy: 0.9617 - val_loss: 0.1327
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9607 - loss: 0.1304 - val_accuracy: 0.9687 - val_loss: 0.1096
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9694 - loss: 0.1012 - val_accuracy: 0.9653 - val_loss: 0.1170
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9687 - loss: 0.1015 - val_accuracy: 0.9711 - val_loss: 0.1021
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9709 - loss: 0.0955 - val_accuracy: 0.9674 - val_loss: 0.1103
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9763 - loss: 0.0771 - val_accuracy: 0.9736 - val_loss: 0.0918
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9751 - loss: 0.0801 - val_accuracy: 0.9698 - val_loss: 0.1045
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9778 - loss: 0.0700 - val_accuracy: 0.9685 - val_loss: 0.1030

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Test loss: {loss:.4f}, Test accuracy: {accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9622 - loss: 0.1272
# Test loss: 0.1105, Test accuracy: 0.9667
